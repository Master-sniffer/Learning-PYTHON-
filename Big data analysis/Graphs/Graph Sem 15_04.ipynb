# %% [markdown]
# # Imports

# %%
import itertools
import networkx as nx
import numpy.random as rnd
import matplotlib.pyplot as plt
import random
import numpy as np

# %% [markdown]
# # Code

# %%
class Task:
  def __init__(self):
    graph = nx.gnp_random_graph(50, 0.06, random.randint(5,9))
    plt.figure(figsize=(12,12))
    nx.draw(graph, with_labels=True, node_size=300)
    for i in graph.edges():
      graph[i[0]][i[1]]['weight'] = random.randint(1,10)

Task()
